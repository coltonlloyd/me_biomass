# %%
import pandas as pd
from matplotlib import pyplot as plt
from math import log2, log10
import pickle
import cobra
import cobrame
from glob import glob
# %matplotlib inline
# Out:
# /home/sbrg-cjlloyd/cobrapy/cobra/io/__init__.py:12: UserWarning: cobra.io.sbml requires libsbml
#   warn("cobra.io.sbml requires libsbml")

# %%
# Todo, allow shadow prices and reduced costs to be run at the same time

# %%
plt.rcParams['figure.figsize'] = [14.0, 6.0]
plt.rcParams['axes.labelsize'] = 17.0
plt.rcParams['xtick.labelsize'] = 13.0

# %%
with open('/home/sbrg-cjlloyd/multime/multime/iJL1678b_ML_keffs.pickle', 'rb') as f:
    me = pickle.load(f)

# %%
for file in glob('./production_at_5/fluxes.csv'):
    flux_df = pd.read_csv(file, index_col=0)
flux_df[abs(flux_df)<=1e-8] = 0
flux_df = flux_df.T[~ flux_df.columns.isin(['default'])].T
for i in flux_df.columns:
    flux_df.loc['production_flux', i] = flux_df.loc['EX_'+i+'_c', i]

# %%
for kind in ['shadow_wrt_target']:
    joined = pd.DataFrame()
    for file in glob('./production_at_5/%s.csv' % kind):
        df = pd.read_csv(file, index_col=0)
        joined = joined.join(df, how='outer')
joined[(joined <1e-8) & (joined>=0)] = 1e-8
joined[(joined >-1e-8) & (joined<=0)] = -1e-8
df = joined.T[~ joined.columns.isin(['default'])].T
default_series = joined['default']

# %%
norm_flux_df = (flux_df / flux_df.loc['production_flux']).drop('thm', axis=1)
norm_df = (df / flux_df.loc['production_flux']).drop('thm', axis=1)

# %%
change_shadow = (norm_df.T / norm_df.T.median())

# %% [raw]
# fc_change_shadow = (abs(norm_df).applymap(log2).T - abs(norm_df.T.median()).map(log2))

# %%
keep_list = []
for i in change_shadow.columns:
    if i not in me.reactions:
        continue
    elif isinstance(me.reactions.get_by_id(i), cobrame.MetabolicReaction):
        keep_list.append(i)
change_shadow = change_shadow[keep_list]

# %%
keep_list = []
for i in change_shadow.columns:
    if i not in me.metabolites:
        continue
    elif isinstance(me.metabolites.get_by_id(i), cobrame.Complex):
        keep_list.append(i)
change_shadow = change_shadow[keep_list]
df = df.T[keep_list]

# %%
import seaborn as sns
new = change_shadow
new = change_shadow[change_shadow.std().sort_values(ascending=False)[:25].index]
g = sns.clustermap(new, z_score=0)
_ = plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook.py:136 MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.

# %%
import seaborn as sns
new = df
new = df[df.std().sort_values(ascending=False)[:25].index]
g = sns.clustermap(new, z_score=0)
_ = plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook.py:136 MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.

# %%
iml = cobra.io.load_json_model('/home/sbrg-cjlloyd/Desktop/ecoli_M_models/iML1515.json')
flux_df.loc['me_glucose_yield'] = flux_df.loc['production_flux'] / abs(flux_df.loc['EX_glc__D_e'])
for i in flux_df.columns:
    test = iml.copy()
    if i+'_c' not in test.metabolites:
        syn = 0
    else:
        r = cobra.Reaction('EX_%s_c' % i)
        test.add_reaction(r)
        r.add_metabolites({i + '_c': -1})
        test.reactions.BIOMASS_Ec_iML1515_core_75p37M.lower_bound = .5
        test.objective =r
        test.reactions.get_by_id('EX_glc__D_e').lower_bound = flux_df.loc['EX_glc__D_e', i]
        syn = test.optimize().f
    flux_df.loc['m_glucose_yield', i] = syn / 10

# %%
ax = (flux_df.loc['m_glucose_yield'].map(log2) - flux_df.loc['me_glucose_yield'].map(log2) ).plot(kind='bar')
ax.set_ylabel('Log2 fold difference between M-model \n and ME-model yield per glucose')

# %%
g = sns.clustermap(norm_flux_df.corr()**2)
_ = plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook.py:136 MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.

# %%
# Comparing correlations
g = sns.clustermap(norm_df.corr()**2)
_ = plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook.py:136 MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
pca_df = norm_flux_df.fillna(0)
pca_df.drop(['mobd'], axis=1, inplace=True)
expression_values = preprocessing.StandardScaler().fit_transform(pca_df.T)
#expression_values = pca_df
#expression_values = zscore(filtered_df.T, axis=1)
pca = PCA(n_components=5)
a = pca.fit(expression_values)
len(a.components_[0])

print(pca.explained_variance_ratio_)

rxns =pca_df.T.columns
mets = pca_df.T.index
X_r = pca.fit(expression_values).transform(expression_values)

component_dict = {}
for comp_num in [0, 1, 2]:
    comp = a.components_[comp_num]
    component_dict['positive_%s' % comp_num] =  dict(zip(rxns[comp > (abs(comp.mean()) + 1 * comp.std())].values, comp[comp > (abs(comp.mean()) + 2 * comp.std())]))
    component_dict['negative_%s' % comp_num] =  dict(zip(rxns[comp < -(abs(comp.mean()) + 1 * comp.std())].values, comp[comp < -(abs(comp.mean()) + 2 * comp.std())]))

component_df = pd.DataFrame(component_dict).fillna(0)
for i in component_df.index:
    component_df.loc[i, 'min'] = pca_df.loc[i].min()
    component_df.loc[i, 'max'] = pca_df.loc[i].max()
    component_df.loc[i, 'avg'] = pca_df.loc[i].mean()
component_df.to_csv('/home/sbrg-cjlloyd/Desktop/test.csv')
# Out:
# [0.70060803 0.02820452 0.02500155 0.02131901 0.01739817]

# %%
fig, ax = plt.subplots()
for i, met in enumerate(mets):
    #if met in ['thf', 'nac']:
    ax.text(X_r[i, 0], X_r[i, 1], met)
    ax.scatter(X_r[i, 0], X_r[i, 1], s=125)

# %%
component_df.sort_values('positive_1', ascending=True)
# Out:
#                                                     negative_0  negative_1  \
# 2AGPE160tipp_FWD_EG12455-MONOMER                           0.0         0.0
# formation_SUCCORNTRANSAM-CPLX_mod_pydx5p                   0.0         0.0
# formation_SUCCCOASYN                                       0.0         0.0
# formation_SRP-CPLX                                         0.0         0.0
# formation_SAICARSYN-CPLX                                   0.0         0.0
# formation_Rrf_mono                                         0.0         0.0
# formation_RpsU_mono                                        0.0         0.0
# formation_RpsT_mono                                        0.0         0.0
# formation_RpsS_mono                                        0.0         0.0
# formation_RpsR_mono                                        0.0         0.0
# formation_RpsQ_mono                                        0.0         0.0
# formation_RpsP_mono                                        0.0         0.0
# formation_RpsO_mono                                        0.0         0.0
# formation_RpsN_mono                                        0.0         0.0
# formation_RpsM_mono                                        0.0         0.0
# formation_RpsL_mono                                        0.0         0.0
# formation_RpsK_mono                                        0.0         0.0
# formation_RpsJ_mono                                        0.0         0.0
# formation_RpsI_mono                                        0.0         0.0
# formation_RpsH_mono                                        0.0         0.0
# formation_RpsG_mono                                        0.0         0.0
# formation_RpsF_mono                                        0.0         0.0
# formation_SULFITE-REDUCT-CPLX_mod_4fe4s_mod_she...         0.0         0.0
# formation_RpsE_mono                                        0.0         0.0
# formation_Sec-CPLX                                         0.0         0.0
# formation_SecB_tetra                                       0.0         0.0
# formation_UDP-NACMURALA-GLU-LIG-MONOMER_mod_k_m...         0.0         0.0
# formation_UDP-NACMUR-ALA-LIG-MONOMER_mod_mg2               0.0         0.0
# formation_Tyr_RS_dim                                       0.0         0.0
# formation_TufA_mono                                        0.0         0.0
# ...                                                        ...         ...
# charging_tRNA_b3276_GCG                                    0.0         0.0
# formation_EG10370-MONOMER_mod_mn2                          0.0         0.0
# transcription_TU0_4202_from_RpoD_mono                      0.0         0.0
# DM_RNA_b3804                                               0.0         0.0
# charging_tRNA_b4134_UUU                                    0.0         0.0
# transcription_TU00107_from_RpoD_mono                       0.0         0.0
# formation_HEMX-MONOMER                                     0.0         0.0
# translation_b1208                                          0.0         0.0
# transcription_TU00416_from_RpoD_mono                       0.0         0.0
# FCLT_FWD_PROTOHEME-FERROCHELAT-MONOMER                     0.0         0.0
# RNA_b3278_to_generic_16s_rRNAs                             0.0         0.0
# FE3Ri_FWD_FMNREDUCT-MONOMER                                0.0         0.0
# GLUTRR_FWD_CPLX0-3741                                      0.0         0.0
# transcription_TU0_12908_from_RpoD_mono                     0.0         0.0
# formation_CPLX0-7808_mod_mn2                               0.0         0.0
# transcription_TU0_14336_from_RpoD_mono                     0.0         0.0
# formation_EG11110-MONOMER                                  0.0         0.0
# MTHTHFSs_FWD_SPONT                                         0.0         0.0
# charging_tRNA_b0749_AAA                                    0.0         0.0
# SUCBZS_FWD_O-SUCCINYLBENZOATE-COA-SYN-MONOMER_m...         0.0         0.0
# SUCBZL_FWD_MENE-CPLX_mod_mg2                               0.0         0.0
# DHNCOAS_FWD_CPLX0-7882_mod_hco3                            0.0         0.0
# FE3abcpp_FWD_CPLX_dummy                                    0.0         0.0
# formation_CPLX0-7564_mod_nadph_mod_nadh_mod_fad...         0.0         0.0
# transcription_TU0_14609_from_RpoD_mono                     0.0         0.0
# transcription_TU00218_from_RpoD_mono                       0.0         0.0
# DM_RNA_b0673                                               0.0         0.0
# transcription_TU00224_from_RpoD_mono                       0.0         0.0
# translation_b0428                                          0.0         0.0
# formation_DHHB-METHYLTRANSFER-CPLX                         0.0         0.0
#
#                                                     negative_2  positive_0  \
# 2AGPE160tipp_FWD_EG12455-MONOMER                      0.000000    0.026198
# formation_SUCCORNTRANSAM-CPLX_mod_pydx5p              0.000000    0.026198
# formation_SUCCCOASYN                                  0.000000    0.026198
# formation_SRP-CPLX                                    0.000000    0.026198
# formation_SAICARSYN-CPLX                              0.000000    0.026199
# formation_Rrf_mono                                    0.000000    0.026198
# formation_RpsU_mono                                   0.000000    0.026198
# formation_RpsT_mono                                   0.000000    0.026198
# formation_RpsS_mono                                   0.000000    0.026198
# formation_RpsR_mono                                   0.000000    0.026198
# formation_RpsQ_mono                                   0.000000    0.026198
# formation_RpsP_mono                                   0.000000    0.026198
# formation_RpsO_mono                                   0.000000    0.026197
# formation_RpsN_mono                                   0.000000    0.026198
# formation_RpsM_mono                                   0.000000    0.026198
# formation_RpsL_mono                                   0.000000    0.026198
# formation_RpsK_mono                                   0.000000    0.026198
# formation_RpsJ_mono                                   0.000000    0.026198
# formation_RpsI_mono                                   0.000000    0.026198
# formation_RpsH_mono                                   0.000000    0.026198
# formation_RpsG_mono                                   0.000000    0.026198
# formation_RpsF_mono                                   0.000000    0.026198
# formation_SULFITE-REDUCT-CPLX_mod_4fe4s_mod_she...    0.000000    0.026187
# formation_RpsE_mono                                   0.000000    0.026198
# formation_Sec-CPLX                                    0.000000    0.026198
# formation_SecB_tetra                                  0.000000    0.026198
# formation_UDP-NACMURALA-GLU-LIG-MONOMER_mod_k_m...    0.000000    0.026196
# formation_UDP-NACMUR-ALA-LIG-MONOMER_mod_mg2          0.000000    0.026199
# formation_Tyr_RS_dim                                  0.000000    0.026196
# formation_TufA_mono                                   0.000000    0.026200
# ...                                                        ...         ...
# charging_tRNA_b3276_GCG                               0.000000    0.000000
# formation_EG10370-MONOMER_mod_mn2                     0.000000    0.026198
# transcription_TU0_4202_from_RpoD_mono                -0.052926    0.000000
# DM_RNA_b3804                                         -0.102688    0.000000
# charging_tRNA_b4134_UUU                               0.000000    0.000000
# transcription_TU00107_from_RpoD_mono                 -0.102752    0.000000
# formation_HEMX-MONOMER                               -0.102688    0.000000
# translation_b1208                                     0.000000    0.026198
# transcription_TU00416_from_RpoD_mono                 -0.086915    0.000000
# FCLT_FWD_PROTOHEME-FERROCHELAT-MONOMER               -0.087722    0.000000
# RNA_b3278_to_generic_16s_rRNAs                        0.000000    0.000000
# FE3Ri_FWD_FMNREDUCT-MONOMER                          -0.087722    0.023825
# GLUTRR_FWD_CPLX0-3741                                -0.101947    0.000000
# transcription_TU0_12908_from_RpoD_mono               -0.102689    0.000000
# formation_CPLX0-7808_mod_mn2                         -0.052926    0.000000
# transcription_TU0_14336_from_RpoD_mono                0.000000    0.000000
# formation_EG11110-MONOMER                             0.000000    0.000000
# MTHTHFSs_FWD_SPONT                                    0.000000    0.026198
# charging_tRNA_b0749_AAA                              -0.101831    0.000000
# SUCBZS_FWD_O-SUCCINYLBENZOATE-COA-SYN-MONOMER_m...    0.000000    0.000000
# SUCBZL_FWD_MENE-CPLX_mod_mg2                          0.000000    0.000000
# DHNCOAS_FWD_CPLX0-7882_mod_hco3                       0.000000    0.000000
# FE3abcpp_FWD_CPLX_dummy                              -0.101947    0.026198
# formation_CPLX0-7564_mod_nadph_mod_nadh_mod_fad...    0.000000    0.026198
# transcription_TU0_14609_from_RpoD_mono                0.000000    0.000000
# transcription_TU00218_from_RpoD_mono                  0.000000    0.000000
# DM_RNA_b0673                                          0.000000    0.000000
# transcription_TU00224_from_RpoD_mono                 -0.103462    0.000000
# translation_b0428                                    -0.102689    0.000000
# formation_DHHB-METHYLTRANSFER-CPLX                    0.000000    0.000000
#
#                                                     positive_1  positive_2  \
# 2AGPE160tipp_FWD_EG12455-MONOMER                      0.000000    0.000000
# formation_SUCCORNTRANSAM-CPLX_mod_pydx5p              0.000000    0.000000
# formation_SUCCCOASYN                                  0.000000    0.000000
# formation_SRP-CPLX                                    0.000000    0.000000
# formation_SAICARSYN-CPLX                              0.000000    0.000000
# formation_Rrf_mono                                    0.000000    0.000000
# formation_RpsU_mono                                   0.000000    0.000000
# formation_RpsT_mono                                   0.000000    0.000000
# formation_RpsS_mono                                   0.000000    0.000000
# formation_RpsR_mono                                   0.000000    0.000000
# formation_RpsQ_mono                                   0.000000    0.000000
# formation_RpsP_mono                                   0.000000    0.000000
# formation_RpsO_mono                                   0.000000    0.000000
# formation_RpsN_mono                                   0.000000    0.000000
# formation_RpsM_mono                                   0.000000    0.000000
# formation_RpsL_mono                                   0.000000    0.000000
# formation_RpsK_mono                                   0.000000    0.000000
# formation_RpsJ_mono                                   0.000000    0.000000
# formation_RpsI_mono                                   0.000000    0.000000
# formation_RpsH_mono                                   0.000000    0.000000
# formation_RpsG_mono                                   0.000000    0.000000
# formation_RpsF_mono                                   0.000000    0.000000
# formation_SULFITE-REDUCT-CPLX_mod_4fe4s_mod_she...    0.000000    0.000000
# formation_RpsE_mono                                   0.000000    0.000000
# formation_Sec-CPLX                                    0.000000    0.000000
# formation_SecB_tetra                                  0.000000    0.000000
# formation_UDP-NACMURALA-GLU-LIG-MONOMER_mod_k_m...    0.000000    0.000000
# formation_UDP-NACMUR-ALA-LIG-MONOMER_mod_mg2          0.000000    0.000000
# formation_Tyr_RS_dim                                  0.000000    0.000000
# formation_TufA_mono                                   0.000000    0.000000
# ...                                                        ...         ...
# charging_tRNA_b3276_GCG                               0.079324    0.067699
# formation_EG10370-MONOMER_mod_mn2                     0.079324    0.040585
# transcription_TU0_4202_from_RpoD_mono                 0.079324    0.000000
# DM_RNA_b3804                                          0.079324    0.000000
# charging_tRNA_b4134_UUU                               0.079324    0.059892
# transcription_TU00107_from_RpoD_mono                  0.079324    0.000000
# formation_HEMX-MONOMER                                0.079324    0.000000
# translation_b1208                                     0.079324    0.000000
# transcription_TU00416_from_RpoD_mono                  0.079324    0.000000
# FCLT_FWD_PROTOHEME-FERROCHELAT-MONOMER                0.079337    0.000000
# RNA_b3278_to_generic_16s_rRNAs                        0.079337    0.051752
# FE3Ri_FWD_FMNREDUCT-MONOMER                           0.079337    0.000000
# GLUTRR_FWD_CPLX0-3741                                 0.079337    0.000000
# transcription_TU0_12908_from_RpoD_mono                0.079337    0.000000
# formation_CPLX0-7808_mod_mn2                          0.079337    0.000000
# transcription_TU0_14336_from_RpoD_mono                0.079337    0.067699
# formation_EG11110-MONOMER                             0.079337    0.022649
# MTHTHFSs_FWD_SPONT                                    0.079337    0.055200
# charging_tRNA_b0749_AAA                               0.079651    0.000000
# SUCBZS_FWD_O-SUCCINYLBENZOATE-COA-SYN-MONOMER_m...    0.080334    0.060284
# SUCBZL_FWD_MENE-CPLX_mod_mg2                          0.081914    0.042803
# DHNCOAS_FWD_CPLX0-7882_mod_hco3                       0.082417    0.044031
# FE3abcpp_FWD_CPLX_dummy                               0.082417    0.000000
# formation_CPLX0-7564_mod_nadph_mod_nadh_mod_fad...    0.082417    0.055200
# transcription_TU0_14609_from_RpoD_mono                0.082417    0.061630
# transcription_TU00218_from_RpoD_mono                  0.087020    0.059892
# DM_RNA_b0673                                          0.087216    0.031645
# transcription_TU00224_from_RpoD_mono                  0.087216    0.000000
# translation_b0428                                     0.098453    0.000000
# formation_DHHB-METHYLTRANSFER-CPLX                    0.098453    0.055200
#
#                                                              min  \
# 2AGPE160tipp_FWD_EG12455-MONOMER                    3.399320e-05
# formation_SUCCORNTRANSAM-CPLX_mod_pydx5p            5.335437e-08
# formation_SUCCCOASYN                                1.535457e-07
# formation_SRP-CPLX                                  9.853612e-09
# formation_SAICARSYN-CPLX                            1.105590e-07
# formation_Rrf_mono                                  4.429762e-10
# formation_RpsU_mono                                 7.110963e-07
# formation_RpsT_mono                                 7.110963e-07
# formation_RpsS_mono                                 7.110963e-07
# formation_RpsR_mono                                 7.110963e-07
# formation_RpsQ_mono                                 7.110963e-07
# formation_RpsP_mono                                 7.110963e-07
# formation_RpsO_mono                                 7.110963e-07
# formation_RpsN_mono                                 7.110963e-07
# formation_RpsM_mono                                 7.110963e-07
# formation_RpsL_mono                                 7.110963e-07
# formation_RpsK_mono                                 7.110963e-07
# formation_RpsJ_mono                                 7.111039e-07
# formation_RpsI_mono                                 7.110963e-07
# formation_RpsH_mono                                 7.110963e-07
# formation_RpsG_mono                                 7.110963e-07
# formation_RpsF_mono                                 7.110963e-07
# formation_SULFITE-REDUCT-CPLX_mod_4fe4s_mod_she...  1.271581e-08
# formation_RpsE_mono                                 7.110963e-07
# formation_Sec-CPLX                                  1.534679e-08
# formation_SecB_tetra                                5.495569e-09
# formation_UDP-NACMURALA-GLU-LIG-MONOMER_mod_k_m...  1.257699e-09
# formation_UDP-NACMUR-ALA-LIG-MONOMER_mod_mg2        2.605234e-09
# formation_Tyr_RS_dim                                3.330906e-09
# formation_TufA_mono                                 1.184386e-07
# ...                                                          ...
# charging_tRNA_b3276_GCG                             0.000000e+00
# formation_EG10370-MONOMER_mod_mn2                   1.182647e-09
# transcription_TU0_4202_from_RpoD_mono               0.000000e+00
# DM_RNA_b3804                                        0.000000e+00
# charging_tRNA_b4134_UUU                             0.000000e+00
# transcription_TU00107_from_RpoD_mono                0.000000e+00
# formation_HEMX-MONOMER                              0.000000e+00
# translation_b1208                                   4.990441e-09
# transcription_TU00416_from_RpoD_mono                0.000000e+00
# FCLT_FWD_PROTOHEME-FERROCHELAT-MONOMER              1.380972e-07
# RNA_b3278_to_generic_16s_rRNAs                      0.000000e+00
# FE3Ri_FWD_FMNREDUCT-MONOMER                         9.456647e-07
# GLUTRR_FWD_CPLX0-3741                               1.206504e-06
# transcription_TU0_12908_from_RpoD_mono              0.000000e+00
# formation_CPLX0-7808_mod_mn2                        0.000000e+00
# transcription_TU0_14336_from_RpoD_mono              0.000000e+00
# formation_EG11110-MONOMER                           0.000000e+00
# MTHTHFSs_FWD_SPONT                                  3.487717e-05
# charging_tRNA_b0749_AAA                             0.000000e+00
# SUCBZS_FWD_O-SUCCINYLBENZOATE-COA-SYN-MONOMER_m...  0.000000e+00
# SUCBZL_FWD_MENE-CPLX_mod_mg2                        0.000000e+00
# DHNCOAS_FWD_CPLX0-7882_mod_hco3                     0.000000e+00
# FE3abcpp_FWD_CPLX_dummy                             1.903541e-06
# formation_CPLX0-7564_mod_nadph_mod_nadh_mod_fad...  3.771845e-09
# transcription_TU0_14609_from_RpoD_mono              0.000000e+00
# transcription_TU00218_from_RpoD_mono                0.000000e+00
# DM_RNA_b0673                                        0.000000e+00
# transcription_TU00224_from_RpoD_mono                0.000000e+00
# translation_b0428                                   0.000000e+00
# formation_DHHB-METHYLTRANSFER-CPLX                  0.000000e+00
#
#                                                              max           avg
# 2AGPE160tipp_FWD_EG12455-MONOMER                    1.637120e+01  3.535902e-01
# formation_SUCCORNTRANSAM-CPLX_mod_pydx5p            2.812437e-02  6.066042e-04
# formation_SUCCCOASYN                                7.287991e-02  1.573489e-03
# formation_SRP-CPLX                                  3.640282e-03  7.866248e-05
# formation_SAICARSYN-CPLX                            5.513651e-02  1.205359e-03
# formation_Rrf_mono                                  2.384126e-04  5.150066e-06
# formation_RpsU_mono                                 3.452377e-01  7.452696e-03
# formation_RpsT_mono                                 3.452377e-01  7.452696e-03
# formation_RpsS_mono                                 3.452377e-01  7.452696e-03
# formation_RpsR_mono                                 3.452377e-01  7.452696e-03
# formation_RpsQ_mono                                 3.452377e-01  7.452696e-03
# formation_RpsP_mono                                 3.452377e-01  7.452696e-03
# formation_RpsO_mono                                 3.452377e-01  7.452696e-03
# formation_RpsN_mono                                 3.452377e-01  7.452696e-03
# formation_RpsM_mono                                 3.452377e-01  7.452696e-03
# formation_RpsL_mono                                 3.452377e-01  7.452696e-03
# formation_RpsK_mono                                 3.452377e-01  7.452696e-03
# formation_RpsJ_mono                                 3.452413e-01  7.452774e-03
# formation_RpsI_mono                                 3.452377e-01  7.452696e-03
# formation_RpsH_mono                                 3.452377e-01  7.452696e-03
# formation_RpsG_mono                                 3.452377e-01  7.452696e-03
# formation_RpsF_mono                                 3.452377e-01  7.452696e-03
# formation_SULFITE-REDUCT-CPLX_mod_4fe4s_mod_she...  7.358355e-03  1.583269e-04
# formation_RpsE_mono                                 3.452377e-01  7.452696e-03
# formation_Sec-CPLX                                  4.357446e-03  9.418823e-05
# formation_SecB_tetra                                7.201157e-04  1.558963e-05
# formation_UDP-NACMURALA-GLU-LIG-MONOMER_mod_k_m...  6.057116e-04  1.308234e-05
# formation_UDP-NACMUR-ALA-LIG-MONOMER_mod_mg2        1.254688e-03  2.709913e-05
# formation_Tyr_RS_dim                                1.354764e-03  2.940617e-05
# formation_TufA_mono                                 5.747864e-02  1.240796e-03
# ...                                                          ...           ...
# charging_tRNA_b3276_GCG                             4.685292e+00  5.061810e-01
# formation_EG10370-MONOMER_mod_mn2                   5.679285e-04  4.264916e-05
# transcription_TU0_4202_from_RpoD_mono               3.726327e-07  2.235745e-08
# DM_RNA_b3804                                        4.130520e-07  2.478284e-08
# charging_tRNA_b4134_UUU                             3.931513e+00  7.945477e-02
# transcription_TU00107_from_RpoD_mono                2.085474e-07  1.316790e-08
# formation_HEMX-MONOMER                              5.495952e-05  1.099190e-06
# translation_b1208                                   2.396500e-03  1.799676e-04
# transcription_TU00416_from_RpoD_mono                2.373125e-07  1.498416e-08
# FCLT_FWD_PROTOHEME-FERROCHELAT-MONOMER              1.000128e+00  6.125303e-02
# RNA_b3278_to_generic_16s_rRNAs                      4.937428e-04  4.172267e-05
# FE3Ri_FWD_FMNREDUCT-MONOMER                         6.276988e-01  5.329982e-02
# GLUTRR_FWD_CPLX0-3741                               8.004687e+00  6.512909e-01
# transcription_TU0_12908_from_RpoD_mono              8.233029e-06  6.584183e-07
# formation_CPLX0-7808_mod_mn2                        5.556267e-04  3.333733e-05
# transcription_TU0_14336_from_RpoD_mono              2.477862e-07  4.955723e-09
# formation_EG11110-MONOMER                           1.651830e-05  3.303661e-07
# MTHTHFSs_FWD_SPONT                                  1.786032e+01  5.043083e-01
# charging_tRNA_b0749_AAA                             1.079132e-01  3.246794e-03
# SUCBZS_FWD_O-SUCCINYLBENZOATE-COA-SYN-MONOMER_m...  1.000000e+00  2.000000e-02
# SUCBZL_FWD_MENE-CPLX_mod_mg2                        1.000000e+00  2.000000e-02
# DHNCOAS_FWD_CPLX0-7882_mod_hco3                     1.000000e+00  2.000000e-02
# FE3abcpp_FWD_CPLX_dummy                             1.260917e+00  1.067194e-01
# formation_CPLX0-7564_mod_nadph_mod_nadh_mod_fad...  1.811308e-03  1.360220e-04
# transcription_TU0_14609_from_RpoD_mono              8.818502e-07  1.763700e-08
# transcription_TU00218_from_RpoD_mono                1.077946e-06  5.084773e-08
# DM_RNA_b0673                                        9.082828e-05  2.391747e-06
# transcription_TU00224_from_RpoD_mono                1.892700e-07  1.396797e-08
# translation_b0428                                   2.737547e-05  5.475094e-07
# formation_DHHB-METHYLTRANSFER-CPLX                  4.908736e-05  9.817472e-07
#
# [1724 rows x 9 columns]
